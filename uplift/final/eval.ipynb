# %%
import os

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
name = 'search'

# %%
hist_ss = pd.read_csv(os.path.join('metrics', f'{name}_hist.csv'),
                      index_col=0,
                      squeeze=True)
metrics_df = pd.read_csv(os.path.join('metrics', f'{name}_metrics.csv'))
example_df = pd.read_csv(os.path.join('metrics', f'{name}_examples.csv'))

# %%
plt.figure(figsize=(20, 5))
hist_ss.plot.bar()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20, 5))
plt.xticks(np.around(np.arange(min(metrics_df['k']), max(metrics_df['k']) + 0.02, 0.02), 2))
metrics_df.set_index('k')['mean'].plot.line()
# Out:
# <AxesSubplot:xlabel='k'>

# %%
plt.figure(figsize=(20, 5))
metrics_df.set_index('k')['std'].plot.line()
# Out:
# <AxesSubplot:xlabel='k'>

# %%
bins = pd.qcut(example_df['purchases_30d__count'], q=10, duplicates='drop')
example_df.groupby(['w', bins]).agg({'y': 'mean',
                                     'uplift': 'mean'})
# Out:
#                                    y     uplift
# w   purchases_30d__count
# 0.0 (0.999, 2.0]          202.829050  -3.287284
#     (2.0, 3.0]            256.898960 -15.923040
#     (3.0, 4.0]            257.694675 -19.189144
#     (4.0, 10.0]           258.426936 -21.076468
# 1.0 (0.999, 2.0]          206.625274  -3.219477
#     (2.0, 3.0]            244.126343 -15.980502
#     (3.0, 4.0]            237.370450 -19.068650
#     (4.0, 10.0]           237.842184 -21.151377

# %%
bins = pd.qcut(example_df['purchases_sum_30d__sum'], q=10, duplicates='drop')
example_df.groupby(['w', bins]).agg({'y': 'mean',
                                     'uplift': 'mean'})
# Out:
#                                             y     uplift
# w   purchases_sum_30d__sum
# 0.0 (85.02799999999999, 1027.773]  113.381924   2.271041
#     (1027.773, 1486.169]           142.074634  -0.866665
#     (1486.169, 1908.069]           172.041740  -4.164490
#     (1908.069, 2328.167]           193.264216  -6.677920
#     (2328.167, 2760.356]           213.981228  -9.332374
#     (2760.356, 3244.932]           229.691224 -11.252410
#     (3244.932, 3843.417]           255.955372 -12.876972
#     (3843.417, 4613.921]           294.961684 -14.019892
#     (4613.921, 5664.935]           327.691156 -18.781370
#     (5664.935, 10710.174]          300.287233 -13.885297
# 1.0 (85.02799999999999, 1027.773]  117.004555   2.359264
#     (1027.773, 1486.169]           144.466157  -0.656716
#     (1486.169, 1908.069]           171.611987  -4.030513
#     (1908.069, 2328.167]           191.135324  -6.819756
#     (2328.167, 2760.356]           210.865792  -9.180736
#     (2760.356, 3244.932]           226.932555 -11.194627
#     (3244.932, 3843.417]           246.437779 -13.027105
#     (3843.417, 4613.921]           283.993177 -13.975847
#     (4613.921, 5664.935]           315.891878 -18.514033
#     (5664.935, 10710.174]          294.078754 -14.062822
