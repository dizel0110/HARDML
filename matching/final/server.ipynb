# %%
# %env VOCAB_PATH=/home/jupyter-v.pashentsev-2/2.matching/5/vocab.json
# %env EMB_PATH_KNRM=/home/jupyter-v.pashentsev-2/2.matching/5/embedings.pickle
# %env EMB_PATH_GLOVE=/home/jupyter-v.pashentsev-2/2.matching/5/data/glove.6B.50d.txt
# %env MLP_PATH=/home/jupyter-v.pashentsev-2/2.matching/5/mlp.pickle
# Out:
# env: VOCAB_PATH=/home/jupyter-v.pashentsev-2/2.matching/5/vocab.json
# env: EMB_PATH_KNRM=/home/jupyter-v.pashentsev-2/2.matching/5/embedings.pickle
# env: EMB_PATH_GLOVE=/home/jupyter-v.pashentsev-2/2.matching/5/data/glove.6B.50d.txt
# env: MLP_PATH=/home/jupyter-v.pashentsev-2/2.matching/5/mlp.pickle

# %%
# !FLASK_APP=solution_final.py FLASK_ENV=development flask run --port 11000
# Out:
#  * Serving Flask app "solution_final.py" (lazy loading)
#  * Environment: development
#  * Debug mode: on
#  * Running on http://127.0.0.1:11000/ (Press CTRL+C to quit)
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 189-611-939
# 127.0.0.1 - - [18/Jun/2021 08:25:13] "GET /ping HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/opt/tljh/user/lib/python3.7/site-packages/flask/cli.py", line 338, in __call__
#     self._flush_bg_loading_exception()
#   File "/opt/tljh/user/lib/python3.7/site-packages/flask/cli.py", line 326, in _flush_bg_loading_exception
#     reraise(*exc_info)
#   File "/opt/tljh/user/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/tljh/user/lib/python3.7/site-packages/flask/cli.py", line 314, in _load_app
#     self._load_unlocked()
#   File "/opt/tljh/user/lib/python3.7/site-packages/flask/cli.py", line 330, in _load_unlocked
#     self._app = rv = self.loader()
# ...

# %%
# !FLASK_APP=solution_final.py flask run --port 11000
# Out:
#  * Serving Flask app "solution_final.py"
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:11000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [17/Jun/2021 23:16:33] "GET /ping HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jun/2021 23:16:35] "GET /ping HTTP/1.1" 200 -
# ^C
