# %%
# %%writefile solution_6.py
from collections import OrderedDict, defaultdict
from typing import Callable, Tuple, Dict, List

import numpy as np
import scipy.spatial.distance as dist
from tqdm.auto import tqdm


def distance(pointA: np.ndarray, documents: np.ndarray) -> np.ndarray:
    return dist.cdist(pointA, documents).reshape(-1, 1)


def create_sw_graph(
        data: np.ndarray,
        num_candidates_for_choice_long: int = 10,
        num_edges_long: int = 5,
        num_candidates_for_choice_short: int = 10,
        num_edges_short: int = 5,
        use_sampling: bool = False,
        sampling_share: float = 0.05,
        dist_f: Callable = distance
    ) -> Dict[int, List[int]]:    
    graph = {}
    
    for i in range(len(data)):
        distances = dist_f(data[i].reshape(1,-1),
                           data)
        distances = distances.reshape(-1)
                
        order_short = distances.argsort()
        order_short = order_short[order_short != i]
        idx_short_select = np.random.choice(num_candidates_for_choice_short,
                                      size=num_edges_short,
                                      replace=False)
        
        graph[i] = order_short[idx_short_select].tolist()
        
        order_long = distances.argsort()[::-1]
        order_long = order_long[order_long != i]
        idx_long_select = np.random.choice(num_candidates_for_choice_long,
                                      size=num_edges_long,
                                      replace=False)
        
        graph[i] += order_long[idx_long_select].tolist()
    
    return graph
    

def nsw(query_point: np.ndarray, all_documents: np.ndarray, 
        graph_edges: Dict[int, List[int]],
        search_k: int = 10, num_start_points: int = 5,
        dist_f: Callable = distance) -> np.ndarray:
    documents = []
        
    all_edges = np.array(list(graph_edges.keys()))
    
    queue_flag = False
    queue_edges = list()
    queue_distances = list()
    candidates_edges = list()
    candidates_distances = list()
    explored_edges = list()
    distance_min = 1e12
    parent_idx = None
    idx = np.random.choice(all_edges,
                           size=1,
                           replace=False)[0]
    while len(documents) != search_k:
        edges = np.array(graph_edges[idx])
        edges = edges[~np.isin(edges, explored_edges)]
        
        distances = dist_f(query_point.reshape(1, -1),
                           all_documents[edges])
        distances = distances.reshape(-1)
        
        print('-'*50)
        print(f'idx {idx}',
              f'distance_min {distance_min}',
              f'explored_edges {explored_edges}',
              f'queue_edges {queue_edges}',
              f'queue_distances {queue_distances}',
              f'candidates_edges {candidates_edges}',
              f'candidates_distances {candidates_distances}',
              f'dicuments {documents}',
              f'all_edges {graph_edges[idx]}',
              f'filtered_edges {edges}',
              f'distances {distances}',
              f'current_min {distances.min()}',
              f'current_min_idx {edges[distances.argmin()]}',
              sep='\n')
        
        if (distances.min() > distance_min
            and idx not in documents):
            if not queue_flag:
                print('Ini queue')
                queue_flag = True
    
#                 if parent_idx:
#                     edges = np.array(graph_edges[parent_idx])
#                     edges = edges[~np.isin(edges, explored_edges)]

#                     distances = dist_f(query_point.reshape(1, -1),
#                                        all_documents[edges])
#                     distances = distances.reshape(-1)
                    
                queue_edges = list(edges[distances.argsort()])[1:]
                queue_distances = list(np.sort(distances))[1:]
                candidates_edges = list()
                candidates_distances = list()
            explored_edges.append(idx) 
            
            if len(queue_edges) != 0:
                print('Pop queue')
                candidates_edges.append(idx)
                candidates_distances.append(distance_min)
                
                idx = queue_edges[0]
                distance_min = queue_distances[0]
                queue_edges.remove(queue_edges[0])
                queue_distances.remove(queue_distances[0])
            else:
                print('Append')
                queue_flag = False
                documents.append(candidates_edges[np.argmin(candidates_distances)])
                explored_edges = list(documents)
                distance_min = 1e12
                parent_idx = None
                idx = np.random.choice(all_edges[~np.isin(all_edges,
                                                          explored_edges)],
                                       size=1,
                                       replace=False)[0]
        elif (distances.min() > distance_min
              and idx in documents):
            explored_edges.append(idx)     
#             print('Restart')            
            distance_min = 1e12
            idx = np.random.choice(all_edges[~np.isin(all_edges,
                                                      explored_edges)],
                                   size=1,
                                   replace=False)[0]
        else:
            explored_edges.append(idx)     
            parent_idx = idx
            idx = edges[distances.argmin()]
            distance_min = distances.min()   
    return np.array(documents)
# Out:
# Overwriting solution_6.py

# %%
import solution_6
import importlib
importlib.reload(solution_6)
# Out:
# <module 'solution_6' from '/home/jupyter-v.pashentsev-2/2.matching/6/solution_6.py'>

# %%
import numpy as np

# %%
query = np.array([[0.5, 0.5, 0.5]])
docs = np.random.randn(1000, 3)
query.shape, docs.shape
# Out:
# ((1, 3), (1000, 3))

# %%
graph = solution_6.create_sw_graph(docs,
                                   num_candidates_for_choice_long=10,
                                   num_candidates_for_choice_short=10,
                                   num_edges_long=5,
                                   num_edges_short=5)

# %%
idxs = solution_6.nsw(query, docs, graph, search_k=10)
idxs
# Out:
# --------------------------------------------------
# idx 298
# distance_min 1000000000000.0
# explored_edges []
# queue_edges []
# queue_distances []
# candidates_edges []
# candidates_distances []
# dicuments []
# all_edges [334, 365, 617, 670, 848, 965, 777, 197, 567, 233]
# filtered_edges [334 365 617 670 848 965 777 197 567 233]
# distances [1.87577611 1.66493859 2.00731911 1.40790311 1.53691626 3.44371948
#  3.10281949 3.53741185 2.57544111 2.70177146]
# current_min 1.4079031133791322
# current_min_idx 670
# --------------------------------------------------
# idx 670
# distance_min 1.4079031133791322
# explored_edges [298]
# queue_edges []
# queue_distances []
# candidates_edges []
# candidates_distances []
# dicuments []
# all_edges [114, 351, 501, 319, 506, 965, 862, 17, 173, 397]
# filtered_edges [114 351 501 319 506 965 862  17 173 397]
# distances [1.39566629 1.36315269 1.62939074 1.22212865 1.15021392 3.44371948
#  4.13253805 2.54338893 3.70646558 4.20630395]
# current_min 1.1502139169198593
# current_min_idx 506
# --------------------------------------------------
# idx 506
# distance_min 1.1502139169198593
# explored_edges [298, 670]
# queue_edges []
# queue_distances []
# candidates_edges []
# candidates_distances []
# dicuments []
# all_edges [241, 841, 541, 461, 670, 777, 233, 397, 862, 965]
# filtered_edges [241 841 541 461 777 233 397 862 965]
# distances [1.18102907 1.24711866 1.27626957 0.90137383 3.10281949 2.70177146
#  4.20630395 4.13253805 3.44371948]
# current_min 0.9013738301174133
# current_min_idx 461
# --------------------------------------------------
# idx 461
# distance_min 0.9013738301174133
# explored_edges [298, 670, 506]
# queue_edges []
# queue_distances []
# candidates_edges []
# candidates_distances []
# dicuments []
# all_edges [175, 557, 506, 165, 788, 965, 255, 862, 777, 173]
# filtered_edges [175 557 165 788 965 255 862 777 173]
# distances [0.69797379 0.95527661 0.69247541 0.76256807 3.44371948 3.53739171
#  4.13253805 3.10281949 3.70646558]
# current_min 0.6924754081952755
# current_min_idx 165
# --------------------------------------------------
# idx 165
# distance_min 0.6924754081952755
# explored_edges [298, 670, 506, 461]
# queue_edges []
# queue_distances []
# candidates_edges []
# candidates_distances []
# dicuments []
# all_edges [557, 673, 457, 461, 583, 504, 844, 777, 683, 458]
# filtered_edges [557 673 457 583 504 844 777 683 458]
# distances [0.95527661 0.77906531 0.69319482 0.6439184  3.85345474 4.0628634
#  3.10281949 3.72977164 3.5538868 ]
# current_min 0.6439184013369329
# current_min_idx 583
# --------------------------------------------------
# idx 583
# distance_min 0.6439184013369329
# explored_edges [298, 670, 506, 461, 165]
# queue_edges []
# queue_distances []
# candidates_edges []
# candidates_distances []
# dicuments []
# all_edges [299, 48, 589, 457, 832, 458, 844, 530, 862, 683]
# filtered_edges [299  48 589 457 832 458 844 530 862 683]
# distances [0.950045   0.61745946 0.83508286 0.69319482 0.7564629  3.5538868
#  4.0628634  3.93609135 4.13253805 3.72977164]
# current_min 0.6174594627839581
# current_min_idx 48
# --------------------------------------------------
# idx 48
# distance_min 0.6174594627839581
# explored_edges [298, 670, 506, 461, 165, 583]
# queue_edges []
# queue_distances []
# candidates_edges []
# candidates_distances []
# dicuments []
# all_edges [372, 161, 583, 832, 936, 458, 397, 284, 965, 255]
# filtered_edges [372 161 832 936 458 397 284 965 255]
# distances [0.29466198 0.56819929 0.7564629  0.51946286 3.5538868  4.20630395
#  3.97057023 3.44371948 3.53739171]
# current_min 0.294661984193148
# current_min_idx 372
# --------------------------------------------------
# idx 372
# distance_min 0.294661984193148
# explored_edges [298, 670, 506, 461, 165, 583, 48]
# queue_edges []
# queue_distances []
# candidates_edges []
# candidates_distances []
# dicuments []
# all_edges [676, 991, 450, 64, 219, 258, 397, 530, 862, 197]
# filtered_edges [676 991 450  64 219 258 397 530 862 197]
# distances [0.40055827 0.13773955 0.4859671  0.44128276 0.35396236 3.92717392
#  4.20630395 3.93609135 4.13253805 3.53741185]
# current_min 0.1377395463223811
# current_min_idx 991
# --------------------------------------------------
# idx 991
# distance_min 0.1377395463223811
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372]
# queue_edges []
# queue_distances []
# candidates_edges []
# candidates_distances []
# dicuments []
# all_edges [940, 321, 64, 372, 304, 504, 862, 152, 530, 258]
# filtered_edges [940 321  64 304 504 862 152 530 258]
# distances [0.19250725 0.21555906 0.44128276 0.33375966 3.85345474 4.13253805
#  3.93049599 3.93609135 3.92717392]
# current_min 0.19250725122597084
# current_min_idx 940
# Ini queue
# Pop queue
# --------------------------------------------------
# idx 321
# distance_min 0.2155590552705677
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991]
# queue_edges [304, 64, 504, 258, 152, 530, 862]
# queue_distances [0.33375965533537083, 0.4412827576688875, 3.853454743495208, 3.927173922264074, 3.9304959949850096, 3.936091354161183, 4.132538050669699]
# candidates_edges [991]
# candidates_distances [0.1377395463223811]
# dicuments []
# all_edges [773, 940, 759, 889, 20, 198, 844, 504, 862, 258]
# filtered_edges [773 940 759 889  20 198 844 504 862 258]
# distances [0.36658545 0.19250725 0.55657914 0.32212513 0.51244807 3.91011177
#  4.0628634  3.85345474 4.13253805 3.92717392]
# current_min 0.19250725122597084
# current_min_idx 940
# --------------------------------------------------
# idx 940
# distance_min 0.19250725122597084
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321]
# queue_edges [304, 64, 504, 258, 152, 530, 862]
# queue_distances [0.33375965533537083, 0.4412827576688875, 3.853454743495208, 3.927173922264074, 3.9304959949850096, 3.936091354161183, 4.132538050669699]
# candidates_edges [991]
# candidates_distances [0.1377395463223811]
# dicuments []
# all_edges [170, 116, 321, 372, 751, 397, 683, 862, 530, 198]
# filtered_edges [170 116 751 397 683 862 530 198]
# distances [0.5623793  0.40059532 0.43063996 4.20630395 3.72977164 4.13253805
#  3.93609135 3.91011177]
# current_min 0.4005953215502105
# current_min_idx 116
# Pop queue
# --------------------------------------------------
# idx 304
# distance_min 0.33375965533537083
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940]
# queue_edges [64, 504, 258, 152, 530, 862]
# queue_distances [0.4412827576688875, 3.853454743495208, 3.927173922264074, 3.9304959949850096, 3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940]
# candidates_distances [0.1377395463223811, 0.19250725122597084]
# dicuments []
# all_edges [219, 372, 175, 64, 774, 862, 258, 198, 844, 397]
# filtered_edges [219 175  64 774 862 258 198 844 397]
# distances [0.35396236 0.69797379 0.44128276 0.42082444 4.13253805 3.92717392
#  3.91011177 4.0628634  4.20630395]
# current_min 0.35396236267530334
# current_min_idx 219
# Pop queue
# --------------------------------------------------
# idx 64
# distance_min 0.4412827576688875
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304]
# queue_edges [504, 258, 152, 530, 862]
# queue_distances [3.853454743495208, 3.927173922264074, 3.9304959949850096, 3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083]
# dicuments []
# all_edges [372, 304, 743, 175, 819, 645, 258, 198, 844, 197]
# filtered_edges [743 175 819 645 258 198 844 197]
# distances [0.51451373 0.69797379 0.62508917 3.75524275 3.92717392 3.91011177
#  4.0628634  3.53741185]
# current_min 0.5145137256627998
# current_min_idx 743
# Pop queue
# --------------------------------------------------
# idx 504
# distance_min 3.853454743495208
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64]
# queue_edges [258, 152, 530, 862]
# queue_distances [3.927173922264074, 3.9304959949850096, 3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875]
# dicuments []
# all_edges [683, 781, 860, 530, 561, 197, 711, 177, 588, 777]
# filtered_edges [683 781 860 530 561 197 711 177 588 777]
# distances [3.72977164 2.97968161 3.13550243 3.93609135 2.67825144 3.53741185
#  2.66280673 2.71512695 3.62695616 3.10281949]
# current_min 2.662806732935388
# current_min_idx 711
# --------------------------------------------------
# idx 711
# distance_min 2.662806732935388
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504]
# queue_edges [258, 152, 530, 862]
# queue_distances [3.927173922264074, 3.9304959949850096, 3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875]
# dicuments []
# all_edges [312, 268, 828, 348, 36, 781, 242, 504, 530, 719]
# filtered_edges [312 268 828 348  36 781 242 530 719]
# distances [1.92890846 2.15367947 1.85456003 2.38529411 1.86474197 2.97968161
#  3.09099829 3.93609135 3.69500521]
# current_min 1.8545600310217192
# current_min_idx 828
# --------------------------------------------------
# idx 828
# distance_min 1.8545600310217192
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711]
# queue_edges [258, 152, 530, 862]
# queue_distances [3.927173922264074, 3.9304959949850096, 3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875]
# dicuments []
# all_edges [171, 268, 36, 312, 742, 530, 504, 683, 470, 894]
# filtered_edges [171 268  36 312 742 530 683 470 894]
# distances [1.51601167 2.15367947 1.86474197 1.92890846 1.80798596 3.93609135
#  3.72977164 3.06854143 3.75900809]
# current_min 1.5160116679254563
# current_min_idx 171
# --------------------------------------------------
# idx 171
# distance_min 1.5160116679254563
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828]
# queue_edges [258, 152, 530, 862]
# queue_distances [3.927173922264074, 3.9304959949850096, 3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875]
# dicuments []
# all_edges [40, 828, 427, 2, 742, 844, 530, 813, 894, 719]
# filtered_edges [ 40 427   2 742 844 530 813 894 719]
# distances [1.7338512  1.28909592 1.42177385 1.80798596 4.0628634  3.93609135
#  3.30440059 3.75900809 3.69500521]
# current_min 1.2890959245835558
# current_min_idx 427
# --------------------------------------------------
# idx 427
# distance_min 1.2890959245835558
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171]
# queue_edges [258, 152, 530, 862]
# queue_distances [3.927173922264074, 3.9304959949850096, 3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875]
# dicuments []
# all_edges [480, 456, 524, 946, 696, 781, 683, 504, 530, 719]
# filtered_edges [480 456 524 946 696 781 683 530 719]
# distances [1.50501753 0.94923765 1.2882237  1.01322998 1.28494503 2.97968161
#  3.72977164 3.93609135 3.69500521]
# current_min 0.9492376500261182
# current_min_idx 456
# --------------------------------------------------
# idx 456
# distance_min 0.9492376500261182
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427]
# queue_edges [258, 152, 530, 862]
# queue_distances [3.927173922264074, 3.9304959949850096, 3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875]
# dicuments []
# all_edges [946, 427, 983, 886, 134, 719, 844, 530, 683, 258]
# filtered_edges [946 983 886 134 719 844 530 683 258]
# distances [1.01322998 1.28075479 1.25691827 0.74622988 3.69500521 4.0628634
#  3.93609135 3.72977164 3.92717392]
# current_min 0.7462298794219347
# current_min_idx 134
# --------------------------------------------------
# idx 134
# distance_min 0.7462298794219347
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456]
# queue_edges [258, 152, 530, 862]
# queue_distances [3.927173922264074, 3.9304959949850096, 3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875]
# dicuments []
# all_edges [846, 759, 534, 456, 704, 844, 719, 894, 862, 504]
# filtered_edges [846 759 534 704 844 719 894 862]
# distances [0.90834713 0.55657914 0.92188553 0.54563063 4.0628634  3.69500521
#  3.75900809 4.13253805]
# current_min 0.5456306266112265
# current_min_idx 704
# --------------------------------------------------
# idx 704
# distance_min 0.5456306266112265
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134]
# queue_edges [258, 152, 530, 862]
# queue_distances [3.927173922264074, 3.9304959949850096, 3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875]
# dicuments []
# all_edges [134, 170, 676, 759, 926, 894, 683, 504, 530, 458]
# filtered_edges [170 676 759 926 894 683 530 458]
# distances [0.5623793  0.40055827 0.55657914 0.51187244 3.75900809 3.72977164
#  3.93609135 3.5538868 ]
# current_min 0.40055827339625794
# current_min_idx 676
# --------------------------------------------------
# idx 676
# distance_min 0.40055827339625794
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704]
# queue_edges [258, 152, 530, 862]
# queue_distances [3.927173922264074, 3.9304959949850096, 3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875]
# dicuments []
# all_edges [372, 991, 293, 450, 933, 458, 197, 683, 504, 397]
# filtered_edges [293 450 933 458 197 683 397]
# distances [0.59782866 0.4859671  0.62546084 3.5538868  3.53741185 3.72977164
#  4.20630395]
# current_min 0.4859671016599661
# current_min_idx 450
# Pop queue
# --------------------------------------------------
# idx 258
# distance_min 3.927173922264074
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676]
# queue_edges [152, 530, 862]
# queue_distances [3.9304959949850096, 3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794]
# dicuments []
# all_edges [503, 744, 709, 88, 45, 720, 379, 777, 41, 370]
# filtered_edges [503 744 709  88  45 720 379 777  41 370]
# distances [2.69428356 2.98276902 2.95645959 2.79415127 2.95078413 1.75318339
#  2.24070758 3.10281949 2.15162925 2.19685573]
# current_min 1.753183390619749
# current_min_idx 720
# --------------------------------------------------
# idx 720
# distance_min 1.753183390619749
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258]
# queue_edges [152, 530, 862]
# queue_distances [3.9304959949850096, 3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794]
# dicuments []
# all_edges [446, 50, 512, 637, 913, 645, 112, 949, 764, 152]
# filtered_edges [446  50 512 637 913 645 112 949 764 152]
# distances [1.20243191 1.50833012 1.55696801 1.5147198  1.19825352 3.75524275
#  3.63921412 3.58535921 3.58935156 3.93049599]
# current_min 1.198253521109447
# current_min_idx 913
# --------------------------------------------------
# idx 913
# distance_min 1.198253521109447
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720]
# queue_edges [152, 530, 862]
# queue_distances [3.9304959949850096, 3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794]
# dicuments []
# all_edges [221, 308, 141, 50, 878, 56, 258, 645, 198, 112]
# filtered_edges [221 308 141  50 878  56 645 198 112]
# distances [1.12623346 1.0880446  0.81542387 1.50833012 1.1951593  3.71195037
#  3.75524275 3.91011177 3.63921412]
# current_min 0.8154238708865008
# current_min_idx 141
# --------------------------------------------------
# idx 141
# distance_min 0.8154238708865008
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913]
# queue_edges [152, 530, 862]
# queue_distances [3.9304959949850096, 3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794]
# dicuments []
# all_edges [209, 411, 878, 221, 776, 397, 897, 645, 255, 198]
# filtered_edges [209 411 878 221 776 397 897 645 255 198]
# distances [0.8123273  0.78596873 1.1951593  1.12623346 1.14621494 4.20630395
#  3.49907348 3.75524275 3.53739171 3.91011177]
# current_min 0.7859687292110517
# current_min_idx 411
# --------------------------------------------------
# idx 411
# distance_min 0.7859687292110517
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141]
# queue_edges [152, 530, 862]
# queue_distances [3.9304959949850096, 3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794]
# dicuments []
# all_edges [29, 776, 221, 132, 446, 588, 112, 645, 258, 397]
# filtered_edges [ 29 776 221 132 446 588 112 645 397]
# distances [0.54268127 1.14621494 1.12623346 0.78694828 1.20243191 3.62695616
#  3.63921412 3.75524275 4.20630395]
# current_min 0.5426812730275331
# current_min_idx 29
# --------------------------------------------------
# idx 29
# distance_min 0.5426812730275331
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411]
# queue_edges [152, 530, 862]
# queue_distances [3.9304959949850096, 3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794]
# dicuments []
# all_edges [141, 743, 1, 219, 950, 397, 255, 198, 258, 588]
# filtered_edges [743   1 219 950 397 255 198 588]
# distances [0.51451373 0.83425487 0.35396236 0.50672313 4.20630395 3.53739171
#  3.91011177 3.62695616]
# current_min 0.35396236267530334
# current_min_idx 219
# --------------------------------------------------
# idx 219
# distance_min 0.35396236267530334
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29]
# queue_edges [152, 530, 862]
# queue_distances [3.9304959949850096, 3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794]
# dicuments []
# all_edges [372, 950, 774, 29, 304, 112, 173, 284, 152, 645]
# filtered_edges [950 774 112 173 284 152 645]
# distances [0.50672313 0.42082444 3.63921412 3.70646558 3.97057023 3.93049599
#  3.75524275]
# current_min 0.42082443981989914
# current_min_idx 774
# Pop queue
# --------------------------------------------------
# idx 152
# distance_min 3.9304959949850096
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219]
# queue_edges [530, 862]
# queue_distances [3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676, 219]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334]
# dicuments []
# all_edges [508, 727, 915, 592, 764, 844, 17, 197, 97, 233]
# filtered_edges [508 727 915 592 764 844  17 197  97 233]
# distances [3.15720718 3.28395808 3.12683399 2.61075129 3.58935156 4.0628634
#  2.54338893 3.53741185 2.5181603  2.70177146]
# current_min 2.518160301744369
# current_min_idx 97
# --------------------------------------------------
# idx 97
# distance_min 2.518160301744369
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219, 152]
# queue_edges [530, 862]
# queue_distances [3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676, 219]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334]
# dicuments []
# all_edges [318, 79, 701, 700, 548, 377, 374, 764, 588, 727]
# filtered_edges [318  79 701 700 548 377 374 764 588 727]
# distances [1.79598228 2.34352517 1.98946322 2.18455209 1.87244322 2.94614948
#  2.92993237 3.58935156 3.62695616 3.28395808]
# current_min 1.7959822828028693
# current_min_idx 318
# --------------------------------------------------
# idx 318
# distance_min 1.7959822828028693
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219, 152, 97]
# queue_edges [530, 862]
# queue_distances [3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676, 219]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334]
# dicuments []
# all_edges [701, 51, 691, 34, 274, 588, 871, 727, 764, 894]
# filtered_edges [701  51 691  34 274 588 871 727 764 894]
# distances [1.98946322 1.65746802 1.80881413 1.69196127 1.49085663 3.62695616
#  3.09649637 3.28395808 3.58935156 3.75900809]
# current_min 1.4908566315949898
# current_min_idx 274
# --------------------------------------------------
# idx 274
# distance_min 1.4908566315949898
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318]
# queue_edges [530, 862]
# queue_distances [3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676, 219]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334]
# dicuments []
# all_edges [884, 602, 570, 269, 691, 152, 894, 727, 374, 588]
# filtered_edges [884 602 570 269 691 894 727 374 588]
# distances [1.45096219 1.18579487 1.59348503 1.56193194 1.80881413 3.75900809
#  3.28395808 2.92993237 3.62695616]
# current_min 1.185794871728255
# current_min_idx 602
# --------------------------------------------------
# idx 602
# distance_min 1.185794871728255
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274]
# queue_edges [530, 862]
# queue_distances [3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676, 219]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334]
# dicuments []
# all_edges [259, 314, 231, 497, 904, 152, 530, 645, 764, 198]
# filtered_edges [259 314 231 497 904 530 645 764 198]
# distances [1.20216121 1.0523507  1.19169962 1.30309681 1.13851106 3.93609135
#  3.75524275 3.58935156 3.91011177]
# current_min 1.052350704062833
# current_min_idx 314
# --------------------------------------------------
# idx 314
# distance_min 1.052350704062833
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602]
# queue_edges [530, 862]
# queue_distances [3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676, 219]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334]
# dicuments []
# all_edges [904, 278, 602, 579, 866, 530, 871, 764, 588, 152]
# filtered_edges [904 278 579 866 530 871 764 588]
# distances [1.13851106 1.0045271  0.84297428 0.98565076 3.93609135 3.09649637
#  3.58935156 3.62695616]
# current_min 0.8429742818032321
# current_min_idx 579
# --------------------------------------------------
# idx 579
# distance_min 0.8429742818032321
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314]
# queue_edges [530, 862]
# queue_distances [3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676, 219]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334]
# dicuments []
# all_edges [866, 340, 247, 278, 182, 894, 530, 397, 198, 844]
# filtered_edges [866 340 247 278 182 894 530 397 198 844]
# distances [0.98565076 0.69461001 0.94043991 1.0045271  0.65362778 3.75900809
#  3.93609135 4.20630395 3.91011177 4.0628634 ]
# current_min 0.653627778721039
# current_min_idx 182
# --------------------------------------------------
# idx 182
# distance_min 0.653627778721039
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579]
# queue_edges [530, 862]
# queue_distances [3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676, 219]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334]
# dicuments []
# all_edges [117, 612, 969, 89, 579, 198, 588, 871, 645, 152]
# filtered_edges [117 612 969  89 198 588 871 645]
# distances [0.63287034 0.63117679 0.48443788 0.47531563 3.91011177 3.62695616
#  3.09649637 3.75524275]
# current_min 0.4753156322316352
# current_min_idx 89
# --------------------------------------------------
# idx 89
# distance_min 0.4753156322316352
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 182]
# queue_edges [530, 862]
# queue_distances [3.936091354161183, 4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676, 219]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334]
# dicuments []
# all_edges [182, 294, 186, 969, 605, 862, 894, 588, 258, 152]
# filtered_edges [294 186 969 605 862 894 588]
# distances [0.7117031  0.53628651 0.48443788 0.5561492  4.13253805 3.75900809
#  3.62695616]
# current_min 0.4844378823363078
# current_min_idx 969
# Pop queue
# --------------------------------------------------
# idx 530
# distance_min 3.936091354161183
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 182, 89]
# queue_edges [862]
# queue_distances [4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676, 219, 89]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334, 0.4753156322316352]
# dicuments []
# all_edges [350, 561, 323, 860, 912, 370, 498, 197, 397, 233]
# filtered_edges [350 561 323 860 912 370 498 197 397 233]
# distances [2.78177816 2.67825144 3.00658748 3.13550243 3.18462875 2.19685573
#  2.59587574 3.53741185 4.20630395 2.70177146]
# current_min 2.1968557304923673
# current_min_idx 370
# --------------------------------------------------
# idx 370
# distance_min 2.1968557304923673
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 182, 89, 530]
# queue_edges [862]
# queue_distances [4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676, 219, 89]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334, 0.4753156322316352]
# dicuments []
# all_edges [873, 46, 567, 275, 41, 458, 683, 68, 530, 719]
# filtered_edges [873  46 567 275  41 458 683  68 719]
# distances [1.59742951 1.13686399 2.57544111 1.84046085 2.15162925 3.5538868
#  3.72977164 3.73476344 3.69500521]
# current_min 1.1368639924370034
# current_min_idx 46
# --------------------------------------------------
# idx 46
# distance_min 1.1368639924370034
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 182, 89, 530, 370]
# queue_edges [862]
# queue_distances [4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676, 219, 89]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334, 0.4753156322316352]
# dicuments []
# all_edges [778, 584, 911, 984, 382, 844, 56, 862, 68, 719]
# filtered_edges [778 584 911 984 382 844  56 862  68 719]
# distances [1.39367244 1.25664665 0.58821997 1.1562274  1.63290826 4.0628634
#  3.71195037 4.13253805 3.73476344 3.69500521]
# current_min 0.588219971296158
# current_min_idx 911
# --------------------------------------------------
# idx 911
# distance_min 0.588219971296158
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 182, 89, 530, 370, 46]
# queue_edges [862]
# queue_distances [4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676, 219, 89]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334, 0.4753156322316352]
# dicuments []
# all_edges [110, 796, 539, 321, 405, 530, 198, 683, 68, 719]
# filtered_edges [110 796 539 405 198 683  68 719]
# distances [0.89024401 0.59600825 0.42275926 0.46884599 3.91011177 3.72977164
#  3.73476344 3.69500521]
# current_min 0.4227592602275342
# current_min_idx 539
# --------------------------------------------------
# idx 539
# distance_min 0.4227592602275342
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 182, 89, 530, 370, 46, 911]
# queue_edges [862]
# queue_distances [4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676, 219, 89]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334, 0.4753156322316352]
# dicuments []
# all_edges [643, 911, 210, 950, 116, 284, 530, 504, 68, 862]
# filtered_edges [643 210 950 116 284  68 862]
# distances [0.65318677 0.70964992 0.50672313 0.40059532 3.97057023 3.73476344
#  4.13253805]
# current_min 0.4005953215502105
# current_min_idx 116
# --------------------------------------------------
# idx 116
# distance_min 0.4005953215502105
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 182, 89, 530, 370, 46, 911, 539]
# queue_edges [862]
# queue_distances [4.132538050669699]
# candidates_edges [991, 940, 304, 64, 676, 219, 89]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334, 0.4753156322316352]
# dicuments []
# all_edges [940, 796, 405, 539, 587, 258, 719, 198, 862, 504]
# filtered_edges [796 405 587 719 198 862]
# distances [0.59600825 0.46884599 0.82945374 3.69500521 3.91011177 4.13253805]
# current_min 0.46884599474859917
# current_min_idx 405
# Pop queue
# --------------------------------------------------
# idx 862
# distance_min 4.132538050669699
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 182, 89, 530, 370, 46, 911, 539, 116]
# queue_edges []
# queue_distances []
# candidates_edges [991, 940, 304, 64, 676, 219, 89, 116]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334, 0.4753156322316352, 0.4005953215502105]
# dicuments []
# all_edges [834, 255, 959, 335, 129, 526, 852, 148, 767, 379]
# filtered_edges [834 255 959 335 129 526 852 148 767 379]
# distances [2.97697531 3.53739171 3.41792966 3.24433252 3.14683543 2.1561178
#  2.24507371 1.83883373 2.36818439 2.24070758]
# current_min 1.838833733105591
# current_min_idx 148
# --------------------------------------------------
# idx 148
# distance_min 1.838833733105591
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 182, 89, 530, 370, 46, 911, 539, 116, 862]
# queue_edges []
# queue_distances []
# candidates_edges [991, 940, 304, 64, 676, 219, 89, 116]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334, 0.4753156322316352, 0.4005953215502105]
# dicuments []
# all_edges [891, 878, 526, 303, 451, 397, 965, 112, 284, 255]
# filtered_edges [891 878 526 303 451 397 965 112 284 255]
# distances [1.6333834  1.1951593  2.1561178  1.19379947 1.55750957 4.20630395
#  3.44371948 3.63921412 3.97057023 3.53739171]
# current_min 1.1937994707303412
# current_min_idx 303
# --------------------------------------------------
# idx 303
# distance_min 1.1937994707303412
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 182, 89, 530, 370, 46, 911, 539, 116, 862, 148]
# queue_edges []
# queue_distances []
# candidates_edges [991, 940, 304, 64, 676, 219, 89, 116]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334, 0.4753156322316352, 0.4005953215502105]
# dicuments []
# all_edges [693, 746, 440, 990, 893, 862, 645, 258, 255, 959]
# filtered_edges [693 746 440 990 893 645 255 959]
# distances [1.03454486 1.20413646 1.1603614  1.29426491 1.31586286 3.75524275
#  3.53739171 3.41792966]
# current_min 1.03454485522392
# current_min_idx 693
# --------------------------------------------------
# idx 693
# distance_min 1.03454485522392
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 182, 89, 530, 370, 46, 911, 539, 116, 862, 148, 303]
# queue_edges []
# queue_distances []
# candidates_edges [991, 940, 304, 64, 676, 219, 89, 116]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334, 0.4753156322316352, 0.4005953215502105]
# dicuments []
# all_edges [436, 931, 708, 86, 780, 959, 197, 255, 397, 844]
# filtered_edges [436 931 708  86 780 959 197 255 397 844]
# distances [1.06527416 1.03759688 0.84778544 0.63980181 1.10446338 3.41792966
#  3.53741185 3.53739171 4.20630395 4.0628634 ]
# current_min 0.639801810263964
# current_min_idx 86
# --------------------------------------------------
# idx 86
# distance_min 0.639801810263964
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 182, 89, 530, 370, 46, 911, 539, 116, 862, 148, 303, 693]
# queue_edges []
# queue_distances []
# candidates_edges [991, 940, 304, 64, 676, 219, 89, 116]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334, 0.4753156322316352, 0.4005953215502105]
# dicuments []
# all_edges [693, 153, 751, 402, 161, 197, 258, 844, 255, 965]
# filtered_edges [153 751 402 161 197 844 255 965]
# distances [0.5995635  0.43063996 0.70503312 0.56819929 3.53741185 4.0628634
#  3.53739171 3.44371948]
# current_min 0.43063996162556983
# current_min_idx 751
# --------------------------------------------------
# idx 751
# distance_min 0.43063996162556983
# explored_edges [298, 670, 506, 461, 165, 583, 48, 372, 991, 321, 940, 304, 64, 504, 711, 828, 171, 427, 456, 134, 704, 676, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 182, 89, 530, 370, 46, 911, 539, 116, 862, 148, 303, 693, 86]
# queue_edges []
# queue_distances []
# candidates_edges [991, 940, 304, 64, 676, 219, 89, 116]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334, 0.4753156322316352, 0.4005953215502105]
# dicuments []
# all_edges [402, 832, 457, 936, 881, 862, 530, 284, 397, 258]
# filtered_edges [402 832 457 936 881 284 397]
# distances [0.70503312 0.7564629  0.69319482 0.51946286 0.51029228 3.97057023
#  4.20630395]
# current_min 0.5102922798681011
# current_min_idx 881
# Append
# --------------------------------------------------
# idx 4
# distance_min 1000000000000.0
# explored_edges [991]
# queue_edges []
# queue_distances []
# candidates_edges [991, 940, 304, 64, 676, 219, 89, 116]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334, 0.4753156322316352, 0.4005953215502105]
# dicuments [991]
# all_edges [791, 483, 203, 515, 379, 530, 844, 68, 258, 504]
# filtered_edges [791 483 203 515 379 530 844  68 258 504]
# distances [1.60182307 1.99536595 1.86216308 1.41219853 2.24070758 3.93609135
#  4.0628634  3.73476344 3.92717392 3.85345474]
# current_min 1.4121985302378641
# current_min_idx 515
# --------------------------------------------------
# idx 515
# distance_min 1.4121985302378641
# explored_edges [991, 4]
# queue_edges []
# queue_distances []
# candidates_edges [991, 940, 304, 64, 676, 219, 89, 116]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334, 0.4753156322316352, 0.4005953215502105]
# dicuments [991]
# all_edges [791, 619, 11, 75, 199, 458, 504, 719, 862, 530]
# filtered_edges [791 619  11  75 199 458 504 719 862 530]
# distances [1.60182307 1.71571484 1.34105081 1.72070686 1.00008701 3.5538868
#  3.85345474 3.69500521 4.13253805 3.93609135]
# current_min 1.0000870076166049
# current_min_idx 199
# --------------------------------------------------
# idx 199
# distance_min 1.0000870076166049
# explored_edges [991, 4, 515]
# queue_edges []
# queue_distances []
# candidates_edges [991, 940, 304, 64, 676, 219, 89, 116]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334, 0.4753156322316352, 0.4005953215502105]
# dicuments [991]
# all_edges [799, 881, 163, 665, 589, 458, 397, 862, 844, 504]
# filtered_edges [799 881 163 665 589 458 397 862 844 504]
# distances [0.89364015 0.51029228 0.73552431 1.10376437 0.83508286 3.5538868
#  4.20630395 4.13253805 4.0628634  3.85345474]
# current_min 0.5102922798681011
# current_min_idx 881
# --------------------------------------------------
# idx 881
# distance_min 0.5102922798681011
# explored_edges [991, 4, 515, 199]
# queue_edges []
# queue_distances []
# candidates_edges [991, 940, 304, 64, 676, 219, 89, 116]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334, 0.4753156322316352, 0.4005953215502105]
# dicuments [991]
# all_edges [86, 751, 153, 405, 163, 258, 68, 862, 844, 397]
# filtered_edges [ 86 751 153 405 163 258  68 862 844 397]
# distances [0.63980181 0.43063996 0.5995635  0.46884599 0.73552431 3.92717392
#  3.73476344 4.13253805 4.0628634  4.20630395]
# current_min 0.43063996162556983
# current_min_idx 751
# --------------------------------------------------
# idx 751
# distance_min 0.43063996162556983
# explored_edges [991, 4, 515, 199, 881]
# queue_edges []
# queue_distances []
# candidates_edges [991, 940, 304, 64, 676, 219, 89, 116]
# candidates_distances [0.1377395463223811, 0.19250725122597084, 0.33375965533537083, 0.4412827576688875, 0.40055827339625794, 0.35396236267530334, 0.4753156322316352, 0.4005953215502105]
# dicuments [991]
# all_edges [402, 832, 457, 936, 881, 862, 530, 284, 397, 258]
# filtered_edges [402 832 457 936 862 530 284 397 258]
# distances [0.70503312 0.7564629  0.69319482 0.51946286 4.13253805 3.93609135
#  3.97057023 4.20630395 3.92717392]
# current_min 0.5194628647916658
# current_min_idx 936
# Ini queue
# Pop queue
# --------------------------------------------------
# idx 457
# distance_min 0.6931948187530962
# explored_edges [991, 4, 515, 199, 881, 751]
# queue_edges [402, 832, 258, 530, 284, 862, 397]
# queue_distances [0.7050331193830522, 0.7564628956146718, 3.927173922264074, 3.936091354161183, 3.970570225271179, 4.132538050669699, 4.20630394892048]
# candidates_edges [751]
# candidates_distances [0.43063996162556983]
# dicuments [991]
# all_edges [402, 583, 48, 165, 589, 397, 173, 530, 504, 862]
# filtered_edges [402 583  48 165 589 397 173 530 504 862]
# distances [0.70503312 0.6439184  0.61745946 0.69247541 0.83508286 4.20630395
#  3.70646558 3.93609135 3.85345474 4.13253805]
# current_min 0.6174594627839581
# current_min_idx 48
# --------------------------------------------------
# idx 48
# distance_min 0.6174594627839581
# explored_edges [991, 4, 515, 199, 881, 751, 457]
# queue_edges [402, 832, 258, 530, 284, 862, 397]
# queue_distances [0.7050331193830522, 0.7564628956146718, 3.927173922264074, 3.936091354161183, 3.970570225271179, 4.132538050669699, 4.20630394892048]
# candidates_edges [751]
# candidates_distances [0.43063996162556983]
# dicuments [991]
# all_edges [372, 161, 583, 832, 936, 458, 397, 284, 965, 255]
# filtered_edges [372 161 583 832 936 458 397 284 965 255]
# distances [0.29466198 0.56819929 0.6439184  0.7564629  0.51946286 3.5538868
#  4.20630395 3.97057023 3.44371948 3.53739171]
# current_min 0.294661984193148
# current_min_idx 372
# --------------------------------------------------
# idx 372
# distance_min 0.294661984193148
# explored_edges [991, 4, 515, 199, 881, 751, 457, 48]
# queue_edges [402, 832, 258, 530, 284, 862, 397]
# queue_distances [0.7050331193830522, 0.7564628956146718, 3.927173922264074, 3.936091354161183, 3.970570225271179, 4.132538050669699, 4.20630394892048]
# candidates_edges [751]
# candidates_distances [0.43063996162556983]
# dicuments [991]
# all_edges [676, 991, 450, 64, 219, 258, 397, 530, 862, 197]
# filtered_edges [676 450  64 219 258 397 530 862 197]
# distances [0.40055827 0.4859671  0.44128276 0.35396236 3.92717392 4.20630395
#  3.93609135 4.13253805 3.53741185]
# current_min 0.35396236267530334
# current_min_idx 219
# Pop queue
# --------------------------------------------------
# idx 402
# distance_min 0.7050331193830522
# explored_edges [991, 4, 515, 199, 881, 751, 457, 48, 372]
# queue_edges [832, 258, 530, 284, 862, 397]
# queue_distances [0.7564628956146718, 3.927173922264074, 3.936091354161183, 3.970570225271179, 4.132538050669699, 4.20630394892048]
# candidates_edges [751, 372]
# candidates_distances [0.43063996162556983, 0.294661984193148]
# dicuments [991]
# all_edges [931, 165, 936, 557, 299, 284, 397, 197, 504, 173]
# filtered_edges [931 165 936 557 299 284 397 197 504 173]
# distances [1.03759688 0.69247541 0.51946286 0.95527661 0.950045   3.97057023
#  4.20630395 3.53741185 3.85345474 3.70646558]
# current_min 0.5194628647916658
# current_min_idx 936
# --------------------------------------------------
# idx 936
# distance_min 0.5194628647916658
# explored_edges [991, 4, 515, 199, 881, 751, 457, 48, 372, 402]
# queue_edges [832, 258, 530, 284, 862, 397]
# queue_distances [0.7564628956146718, 3.927173922264074, 3.936091354161183, 3.970570225271179, 4.132538050669699, 4.20630394892048]
# candidates_edges [751, 372]
# candidates_distances [0.43063996162556983, 0.294661984193148]
# dicuments [991]
# all_edges [589, 751, 161, 881, 583, 173, 458, 844, 258, 68]
# filtered_edges [589 161 583 173 458 844 258  68]
# distances [0.83508286 0.56819929 0.6439184  3.70646558 3.5538868  4.0628634
#  3.92717392 3.73476344]
# current_min 0.5681992884255966
# current_min_idx 161
# Pop queue
# --------------------------------------------------
# idx 832
# distance_min 0.7564628956146718
# explored_edges [991, 4, 515, 199, 881, 751, 457, 48, 372, 402, 936]
# queue_edges [258, 530, 284, 862, 397]
# queue_distances [3.927173922264074, 3.936091354161183, 3.970570225271179, 4.132538050669699, 4.20630394892048]
# candidates_edges [751, 372, 936]
# candidates_distances [0.43063996162556983, 0.294661984193148, 0.5194628647916658]
# dicuments [991]
# all_edges [589, 48, 457, 518, 936, 173, 197, 862, 844, 530]
# filtered_edges [589 518 173 197 862 844 530]
# distances [0.83508286 0.97805531 3.70646558 3.53741185 4.13253805 4.0628634
#  3.93609135]
# current_min 0.8350828585791613
# current_min_idx 589
# Pop queue
# --------------------------------------------------
# idx 258
# distance_min 3.927173922264074
# explored_edges [991, 4, 515, 199, 881, 751, 457, 48, 372, 402, 936, 832]
# queue_edges [530, 284, 862, 397]
# queue_distances [3.936091354161183, 3.970570225271179, 4.132538050669699, 4.20630394892048]
# candidates_edges [751, 372, 936, 832]
# candidates_distances [0.43063996162556983, 0.294661984193148, 0.5194628647916658, 0.7564628956146718]
# dicuments [991]
# all_edges [503, 744, 709, 88, 45, 720, 379, 777, 41, 370]
# filtered_edges [503 744 709  88  45 720 379 777  41 370]
# distances [2.69428356 2.98276902 2.95645959 2.79415127 2.95078413 1.75318339
#  2.24070758 3.10281949 2.15162925 2.19685573]
# current_min 1.753183390619749
# current_min_idx 720
# --------------------------------------------------
# idx 720
# distance_min 1.753183390619749
# explored_edges [991, 4, 515, 199, 881, 751, 457, 48, 372, 402, 936, 832, 258]
# queue_edges [530, 284, 862, 397]
# queue_distances [3.936091354161183, 3.970570225271179, 4.132538050669699, 4.20630394892048]
# candidates_edges [751, 372, 936, 832]
# candidates_distances [0.43063996162556983, 0.294661984193148, 0.5194628647916658, 0.7564628956146718]
# dicuments [991]
# all_edges [446, 50, 512, 637, 913, 645, 112, 949, 764, 152]
# filtered_edges [446  50 512 637 913 645 112 949 764 152]
# distances [1.20243191 1.50833012 1.55696801 1.5147198  1.19825352 3.75524275
#  3.63921412 3.58535921 3.58935156 3.93049599]
# current_min 1.198253521109447
# current_min_idx 913
# --------------------------------------------------
# idx 913
# distance_min 1.198253521109447
# explored_edges [991, 4, 515, 199, 881, 751, 457, 48, 372, 402, 936, 832, 258, 720]
# queue_edges [530, 284, 862, 397]
# queue_distances [3.936091354161183, 3.970570225271179, 4.132538050669699, 4.20630394892048]
# candidates_edges [751, 372, 936, 832]
# candidates_distances [0.43063996162556983, 0.294661984193148, 0.5194628647916658, 0.7564628956146718]
# dicuments [991]
# all_edges [221, 308, 141, 50, 878, 56, 258, 645, 198, 112]
# filtered_edges [221 308 141  50 878  56 645 198 112]
# distances [1.12623346 1.0880446  0.81542387 1.50833012 1.1951593  3.71195037
#  3.75524275 3.91011177 3.63921412]
# current_min 0.8154238708865008
# current_min_idx 141
# --------------------------------------------------
# idx 141
# distance_min 0.8154238708865008
# explored_edges [991, 4, 515, 199, 881, 751, 457, 48, 372, 402, 936, 832, 258, 720, 913]
# queue_edges [530, 284, 862, 397]
# queue_distances [3.936091354161183, 3.970570225271179, 4.132538050669699, 4.20630394892048]
# candidates_edges [751, 372, 936, 832]
# candidates_distances [0.43063996162556983, 0.294661984193148, 0.5194628647916658, 0.7564628956146718]
# dicuments [991]
# ...
# all_edges [259, 314, 231, 497, 904, 152, 530, 645, 764, 198]
# filtered_edges [259 314 231 497 904 530 645 764 198]
# distances [1.20216121 1.0523507  1.19169962 1.30309681 1.13851106 3.93609135
#  3.75524275 3.58935156 3.91011177]
# current_min 1.052350704062833
# current_min_idx 314
# --------------------------------------------------
# idx 314
# distance_min 1.052350704062833
# explored_edges [991, 940, 321, 372, 889, 304, 773, 676, 973, 586, 974, 654, 281, 957, 981, 182, 89, 186, 605, 294, 384, 20, 588, 256, 439, 518, 832, 936, 751, 894, 400, 130, 151, 692, 92, 364, 819, 102, 450, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602]
# queue_edges [862]
# queue_distances [4.132538050669699]
# candidates_edges [89, 186, 605, 20, 751, 450, 219]
# candidates_distances [0.4753156322316352, 0.5362865101752721, 0.5561491951248854, 0.5124480680090537, 0.43063996162556983, 0.4859671016599661, 0.35396236267530334]
# dicuments [991, 940, 321, 372, 889, 304, 773, 676, 973]
# all_edges [904, 278, 602, 579, 866, 530, 871, 764, 588, 152]
# filtered_edges [904 278 579 866 530 871 764]
# distances [1.13851106 1.0045271  0.84297428 0.98565076 3.93609135 3.09649637
#  3.58935156]
# current_min 0.8429742818032321
# current_min_idx 579
# --------------------------------------------------
# idx 579
# distance_min 0.8429742818032321
# explored_edges [991, 940, 321, 372, 889, 304, 773, 676, 973, 586, 974, 654, 281, 957, 981, 182, 89, 186, 605, 294, 384, 20, 588, 256, 439, 518, 832, 936, 751, 894, 400, 130, 151, 692, 92, 364, 819, 102, 450, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314]
# queue_edges [862]
# queue_distances [4.132538050669699]
# candidates_edges [89, 186, 605, 20, 751, 450, 219]
# candidates_distances [0.4753156322316352, 0.5362865101752721, 0.5561491951248854, 0.5124480680090537, 0.43063996162556983, 0.4859671016599661, 0.35396236267530334]
# dicuments [991, 940, 321, 372, 889, 304, 773, 676, 973]
# all_edges [866, 340, 247, 278, 182, 894, 530, 397, 198, 844]
# filtered_edges [866 340 247 278 530 397 198 844]
# distances [0.98565076 0.69461001 0.94043991 1.0045271  3.93609135 4.20630395
#  3.91011177 4.0628634 ]
# current_min 0.6946100055283794
# current_min_idx 340
# --------------------------------------------------
# idx 340
# distance_min 0.6946100055283794
# explored_edges [991, 940, 321, 372, 889, 304, 773, 676, 973, 586, 974, 654, 281, 957, 981, 182, 89, 186, 605, 294, 384, 20, 588, 256, 439, 518, 832, 936, 751, 894, 400, 130, 151, 692, 92, 364, 819, 102, 450, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579]
# queue_edges [862]
# queue_distances [4.132538050669699]
# candidates_edges [89, 186, 605, 20, 751, 450, 219]
# candidates_distances [0.4753156322316352, 0.5362865101752721, 0.5561491951248854, 0.5124480680090537, 0.43063996162556983, 0.4859671016599661, 0.35396236267530334]
# dicuments [991, 940, 321, 372, 889, 304, 773, 676, 973]
# all_edges [380, 20, 593, 531, 574, 719, 258, 504, 844, 894]
# filtered_edges [380 593 531 574 719 504 844]
# distances [0.78255701 0.67670395 0.88978807 0.59910119 3.69500521 3.85345474
#  4.0628634 ]
# current_min 0.5991011944106764
# current_min_idx 574
# --------------------------------------------------
# idx 574
# distance_min 0.5991011944106764
# explored_edges [991, 940, 321, 372, 889, 304, 773, 676, 973, 586, 974, 654, 281, 957, 981, 182, 89, 186, 605, 294, 384, 20, 588, 256, 439, 518, 832, 936, 751, 894, 400, 130, 151, 692, 92, 364, 819, 102, 450, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 340]
# queue_edges [862]
# queue_distances [4.132538050669699]
# candidates_edges [89, 186, 605, 20, 751, 450, 219]
# candidates_distances [0.4753156322316352, 0.5362865101752721, 0.5561491951248854, 0.5124480680090537, 0.43063996162556983, 0.4859671016599661, 0.35396236267530334]
# dicuments [991, 940, 321, 372, 889, 304, 773, 676, 973]
# all_edges [410, 340, 759, 293, 973, 894, 504, 258, 397, 152]
# filtered_edges [410 759 293 504 397]
# distances [0.67877239 0.55657914 0.59782866 3.85345474 4.20630395]
# current_min 0.5565791413350712
# current_min_idx 759
# --------------------------------------------------
# idx 759
# distance_min 0.5565791413350712
# explored_edges [991, 940, 321, 372, 889, 304, 773, 676, 973, 586, 974, 654, 281, 957, 981, 182, 89, 186, 605, 294, 384, 20, 588, 256, 439, 518, 832, 936, 751, 894, 400, 130, 151, 692, 92, 364, 819, 102, 450, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 340, 574]
# queue_edges [862]
# queue_distances [4.132538050669699]
# candidates_edges [89, 186, 605, 20, 751, 450, 219]
# candidates_distances [0.4753156322316352, 0.5362865101752721, 0.5561491951248854, 0.5124480680090537, 0.43063996162556983, 0.4859671016599661, 0.35396236267530334]
# dicuments [991, 940, 321, 372, 889, 304, 773, 676, 973]
# all_edges [20, 973, 574, 340, 704, 719, 844, 683, 530, 894]
# filtered_edges [704 719 844 683 530]
# distances [0.54563063 3.69500521 4.0628634  3.72977164 3.93609135]
# current_min 0.5456306266112265
# current_min_idx 704
# --------------------------------------------------
# idx 704
# distance_min 0.5456306266112265
# explored_edges [991, 940, 321, 372, 889, 304, 773, 676, 973, 586, 974, 654, 281, 957, 981, 182, 89, 186, 605, 294, 384, 20, 588, 256, 439, 518, 832, 936, 751, 894, 400, 130, 151, 692, 92, 364, 819, 102, 450, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 340, 574, 759]
# queue_edges [862]
# queue_distances [4.132538050669699]
# candidates_edges [89, 186, 605, 20, 751, 450, 219]
# candidates_distances [0.4753156322316352, 0.5362865101752721, 0.5561491951248854, 0.5124480680090537, 0.43063996162556983, 0.4859671016599661, 0.35396236267530334]
# dicuments [991, 940, 321, 372, 889, 304, 773, 676, 973]
# all_edges [134, 170, 676, 759, 926, 894, 683, 504, 530, 458]
# filtered_edges [134 170 926 683 504 530 458]
# distances [0.74622988 0.5623793  0.51187244 3.72977164 3.85345474 3.93609135
#  3.5538868 ]
# current_min 0.5118724402428889
# current_min_idx 926
# --------------------------------------------------
# idx 926
# distance_min 0.5118724402428889
# explored_edges [991, 940, 321, 372, 889, 304, 773, 676, 973, 586, 974, 654, 281, 957, 981, 182, 89, 186, 605, 294, 384, 20, 588, 256, 439, 518, 832, 936, 751, 894, 400, 130, 151, 692, 92, 364, 819, 102, 450, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 340, 574, 759, 704]
# queue_edges [862]
# queue_distances [4.132538050669699]
# candidates_edges [89, 186, 605, 20, 751, 450, 219]
# candidates_distances [0.4753156322316352, 0.5362865101752721, 0.5561491951248854, 0.5124480680090537, 0.43063996162556983, 0.4859671016599661, 0.35396236267530334]
# dicuments [991, 940, 321, 372, 889, 304, 773, 676, 973]
# all_edges [404, 940, 170, 676, 293, 530, 862, 458, 844, 504]
# filtered_edges [404 170 293 530 862 458 844 504]
# distances [0.76916848 0.5623793  0.59782866 3.93609135 4.13253805 3.5538868
#  4.0628634  3.85345474]
# current_min 0.5623793038300935
# current_min_idx 170
# Pop queue
# --------------------------------------------------
# idx 862
# distance_min 4.132538050669699
# explored_edges [991, 940, 321, 372, 889, 304, 773, 676, 973, 586, 974, 654, 281, 957, 981, 182, 89, 186, 605, 294, 384, 20, 588, 256, 439, 518, 832, 936, 751, 894, 400, 130, 151, 692, 92, 364, 819, 102, 450, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 340, 574, 759, 704, 926]
# queue_edges []
# queue_distances []
# candidates_edges [89, 186, 605, 20, 751, 450, 219, 926]
# candidates_distances [0.4753156322316352, 0.5362865101752721, 0.5561491951248854, 0.5124480680090537, 0.43063996162556983, 0.4859671016599661, 0.35396236267530334, 0.5118724402428889]
# dicuments [991, 940, 321, 372, 889, 304, 773, 676, 973]
# all_edges [834, 255, 959, 335, 129, 526, 852, 148, 767, 379]
# filtered_edges [834 255 959 335 129 526 852 148 767 379]
# distances [2.97697531 3.53739171 3.41792966 3.24433252 3.14683543 2.1561178
#  2.24507371 1.83883373 2.36818439 2.24070758]
# current_min 1.838833733105591
# current_min_idx 148
# --------------------------------------------------
# idx 148
# distance_min 1.838833733105591
# explored_edges [991, 940, 321, 372, 889, 304, 773, 676, 973, 586, 974, 654, 281, 957, 981, 182, 89, 186, 605, 294, 384, 20, 588, 256, 439, 518, 832, 936, 751, 894, 400, 130, 151, 692, 92, 364, 819, 102, 450, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 340, 574, 759, 704, 926, 862]
# queue_edges []
# queue_distances []
# candidates_edges [89, 186, 605, 20, 751, 450, 219, 926]
# candidates_distances [0.4753156322316352, 0.5362865101752721, 0.5561491951248854, 0.5124480680090537, 0.43063996162556983, 0.4859671016599661, 0.35396236267530334, 0.5118724402428889]
# dicuments [991, 940, 321, 372, 889, 304, 773, 676, 973]
# all_edges [891, 878, 526, 303, 451, 397, 965, 112, 284, 255]
# filtered_edges [891 878 526 303 451 397 965 112 284 255]
# distances [1.6333834  1.1951593  2.1561178  1.19379947 1.55750957 4.20630395
#  3.44371948 3.63921412 3.97057023 3.53739171]
# current_min 1.1937994707303412
# current_min_idx 303
# --------------------------------------------------
# idx 303
# distance_min 1.1937994707303412
# explored_edges [991, 940, 321, 372, 889, 304, 773, 676, 973, 586, 974, 654, 281, 957, 981, 182, 89, 186, 605, 294, 384, 20, 588, 256, 439, 518, 832, 936, 751, 894, 400, 130, 151, 692, 92, 364, 819, 102, 450, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 340, 574, 759, 704, 926, 862, 148]
# queue_edges []
# queue_distances []
# candidates_edges [89, 186, 605, 20, 751, 450, 219, 926]
# candidates_distances [0.4753156322316352, 0.5362865101752721, 0.5561491951248854, 0.5124480680090537, 0.43063996162556983, 0.4859671016599661, 0.35396236267530334, 0.5118724402428889]
# dicuments [991, 940, 321, 372, 889, 304, 773, 676, 973]
# all_edges [693, 746, 440, 990, 893, 862, 645, 258, 255, 959]
# filtered_edges [693 746 440 990 893 645 255 959]
# distances [1.03454486 1.20413646 1.1603614  1.29426491 1.31586286 3.75524275
#  3.53739171 3.41792966]
# current_min 1.03454485522392
# current_min_idx 693
# --------------------------------------------------
# idx 693
# distance_min 1.03454485522392
# explored_edges [991, 940, 321, 372, 889, 304, 773, 676, 973, 586, 974, 654, 281, 957, 981, 182, 89, 186, 605, 294, 384, 20, 588, 256, 439, 518, 832, 936, 751, 894, 400, 130, 151, 692, 92, 364, 819, 102, 450, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 340, 574, 759, 704, 926, 862, 148, 303]
# queue_edges []
# queue_distances []
# candidates_edges [89, 186, 605, 20, 751, 450, 219, 926]
# candidates_distances [0.4753156322316352, 0.5362865101752721, 0.5561491951248854, 0.5124480680090537, 0.43063996162556983, 0.4859671016599661, 0.35396236267530334, 0.5118724402428889]
# dicuments [991, 940, 321, 372, 889, 304, 773, 676, 973]
# all_edges [436, 931, 708, 86, 780, 959, 197, 255, 397, 844]
# filtered_edges [436 931 708  86 780 959 197 255 397 844]
# distances [1.06527416 1.03759688 0.84778544 0.63980181 1.10446338 3.41792966
#  3.53741185 3.53739171 4.20630395 4.0628634 ]
# current_min 0.639801810263964
# current_min_idx 86
# --------------------------------------------------
# idx 86
# distance_min 0.639801810263964
# explored_edges [991, 940, 321, 372, 889, 304, 773, 676, 973, 586, 974, 654, 281, 957, 981, 182, 89, 186, 605, 294, 384, 20, 588, 256, 439, 518, 832, 936, 751, 894, 400, 130, 151, 692, 92, 364, 819, 102, 450, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 340, 574, 759, 704, 926, 862, 148, 303, 693]
# queue_edges []
# queue_distances []
# candidates_edges [89, 186, 605, 20, 751, 450, 219, 926]
# candidates_distances [0.4753156322316352, 0.5362865101752721, 0.5561491951248854, 0.5124480680090537, 0.43063996162556983, 0.4859671016599661, 0.35396236267530334, 0.5118724402428889]
# dicuments [991, 940, 321, 372, 889, 304, 773, 676, 973]
# all_edges [693, 153, 751, 402, 161, 197, 258, 844, 255, 965]
# filtered_edges [153 402 161 197 844 255 965]
# distances [0.5995635  0.70503312 0.56819929 3.53741185 4.0628634  3.53739171
#  3.44371948]
# current_min 0.5681992884255966
# current_min_idx 161
# --------------------------------------------------
# idx 161
# distance_min 0.5681992884255966
# explored_edges [991, 940, 321, 372, 889, 304, 773, 676, 973, 586, 974, 654, 281, 957, 981, 182, 89, 186, 605, 294, 384, 20, 588, 256, 439, 518, 832, 936, 751, 894, 400, 130, 151, 692, 92, 364, 819, 102, 450, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 340, 574, 759, 704, 926, 862, 148, 303, 693, 86]
# queue_edges []
# queue_distances []
# candidates_edges [89, 186, 605, 20, 751, 450, 219, 926]
# candidates_distances [0.4753156322316352, 0.5362865101752721, 0.5561491951248854, 0.5124480680090537, 0.43063996162556983, 0.4859671016599661, 0.35396236267530334, 0.5118724402428889]
# dicuments [991, 940, 321, 372, 889, 304, 773, 676, 973]
# all_edges [936, 881, 402, 163, 751, 68, 173, 258, 397, 683]
# filtered_edges [881 402 163  68 173 397 683]
# distances [0.51029228 0.70503312 0.73552431 3.73476344 3.70646558 4.20630395
#  3.72977164]
# current_min 0.5102922798681011
# current_min_idx 881
# --------------------------------------------------
# idx 881
# distance_min 0.5102922798681011
# explored_edges [991, 940, 321, 372, 889, 304, 773, 676, 973, 586, 974, 654, 281, 957, 981, 182, 89, 186, 605, 294, 384, 20, 588, 256, 439, 518, 832, 936, 751, 894, 400, 130, 151, 692, 92, 364, 819, 102, 450, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 340, 574, 759, 704, 926, 862, 148, 303, 693, 86, 161]
# queue_edges []
# queue_distances []
# candidates_edges [89, 186, 605, 20, 751, 450, 219, 926]
# candidates_distances [0.4753156322316352, 0.5362865101752721, 0.5561491951248854, 0.5124480680090537, 0.43063996162556983, 0.4859671016599661, 0.35396236267530334, 0.5118724402428889]
# dicuments [991, 940, 321, 372, 889, 304, 773, 676, 973]
# all_edges [86, 751, 153, 405, 163, 258, 68, 862, 844, 397]
# filtered_edges [153 405 163  68 844 397]
# distances [0.5995635  0.46884599 0.73552431 3.73476344 4.0628634  4.20630395]
# current_min 0.46884599474859917
# current_min_idx 405
# --------------------------------------------------
# idx 405
# distance_min 0.46884599474859917
# explored_edges [991, 940, 321, 372, 889, 304, 773, 676, 973, 586, 974, 654, 281, 957, 981, 182, 89, 186, 605, 294, 384, 20, 588, 256, 439, 518, 832, 936, 751, 894, 400, 130, 151, 692, 92, 364, 819, 102, 450, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 340, 574, 759, 704, 926, 862, 148, 303, 693, 86, 161, 881]
# queue_edges []
# queue_distances []
# candidates_edges [89, 186, 605, 20, 751, 450, 219, 926]
# candidates_distances [0.4753156322316352, 0.5362865101752721, 0.5561491951248854, 0.5124480680090537, 0.43063996162556983, 0.4859671016599661, 0.35396236267530334, 0.5118724402428889]
# dicuments [991, 940, 321, 372, 889, 304, 773, 676, 973]
# all_edges [116, 911, 201, 205, 950, 284, 68, 844, 173, 152]
# filtered_edges [116 911 201 205 950 284  68 844 173]
# distances [0.40059532 0.58821997 0.91307618 0.50062321 0.50672313 3.97057023
#  3.73476344 4.0628634  3.70646558]
# current_min 0.4005953215502105
# current_min_idx 116
# --------------------------------------------------
# idx 116
# distance_min 0.4005953215502105
# explored_edges [991, 940, 321, 372, 889, 304, 773, 676, 973, 586, 974, 654, 281, 957, 981, 182, 89, 186, 605, 294, 384, 20, 588, 256, 439, 518, 832, 936, 751, 894, 400, 130, 151, 692, 92, 364, 819, 102, 450, 258, 720, 913, 141, 411, 29, 219, 152, 97, 318, 274, 602, 314, 579, 340, 574, 759, 704, 926, 862, 148, 303, 693, 86, 161, 881, 405]
# queue_edges []
# queue_distances []
# candidates_edges [89, 186, 605, 20, 751, 450, 219, 926]
# candidates_distances [0.4753156322316352, 0.5362865101752721, 0.5561491951248854, 0.5124480680090537, 0.43063996162556983, 0.4859671016599661, 0.35396236267530334, 0.5118724402428889]
# dicuments [991, 940, 321, 372, 889, 304, 773, 676, 973]
# all_edges [940, 796, 405, 539, 587, 258, 719, 198, 862, 504]
# filtered_edges [796 539 587 719 198 504]
# distances [0.59600825 0.42275926 0.82945374 3.69500521 3.91011177 3.85345474]
# current_min 0.4227592602275342
# current_min_idx 539
# Append
# array([991, 940, 321, 372, 889, 304, 773, 676, 973, 219])

# %%
idxs
# Out:
# array([991, 940, 321, 372, 889, 304, 773, 676, 973, 219])

# %%
import scipy.spatial.distance as dist

# %%
all_dist = dist.cdist(query, docs).reshape(-1)
all_dist.argsort()[:10]
# Out:
# array([991, 940, 321, 372, 889, 304, 219, 773, 676, 116])

# %%
[id_ for id_ in idxs if id_ not in all_dist.argsort()[:10]]
# Out:
# [973]

# %%
dict(zip(graph[949], dist.cdist(query, docs[graph[949]]).reshape(-1)))

# %%
dict(zip(graph[597], dist.cdist(query, docs[graph[597]]).reshape(-1)))

# %%
dict(zip(graph[826], dist.cdist(query, docs[graph[826]]).reshape(-1)))
